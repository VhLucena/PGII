# %% [markdown]
# # Objective
# - Visual geral dos dados
# - Visualizar os missing values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df101 = pd.read_csv("../../Database/102_Database.csv", encoding='latin-1')

# %%
df301 = pd.read_csv("../../Database/302_TreinoDatabase.csv")

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df101.isnull(), cbar=False)

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df301.isnull(), cbar=False)
